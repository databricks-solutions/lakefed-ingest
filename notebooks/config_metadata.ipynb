-- %%
-- Create control table containing metadata
create or replace table lakefed_bulk_ingest.default.control (
  id bigint generated always as identity,
  job_name string,
  task_collection string,
  src_catalog string,
  src_schema string,
  src_table string,
  sink_catalog string,
  sink_schema string,
  sink_table string,
  load_type string,
  select_list string,
  watermark_col_name string,
  watermark_col_type string,
  watermark_col_start_value string,
  task_enabled boolean
);

-- %%
-- Load sample json for AdventureWorks database into control table
declare or replace metadata_json string;
set var metadata_json = '[
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "Address"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "Address"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.Address",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "Customer"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "Customer"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.Customer",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "CustomerAddress"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "CustomerAddress"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.CustomerAddress",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "Product"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "Product"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.Product",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "ProductCategory"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "ProductCategory"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.ProductCategory",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "ProductDescription"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "ProductDescription"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.ProductDescription",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "ProductModel"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "ProductModel"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.ProductModel",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "ProductModelProductDescription"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "ProductModelProductDescription"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.ProductModelProductDescription",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "SalesOrderDetail"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "SalesOrderDetail"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.SalesOrderDetail",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "SalesOrderHeader"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "SalesOrderHeader"
    },
    "load_settings": {
      "type": "full",
      "query": "select * from lakefed_azuresql.SalesLT.SalesOrderHeader",
      "watermark_col_name": null,
      "watermark_col_type": null,
      "watermark_col_start_value": null
    },
    "task_enabled": 1
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "SalesOrderHeader"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "SalesOrderHeader"
    },
    "load_settings": {
      "type": "incremental",
      "query": "select * from lakefed_azuresql.SalesLT.SalesOrderHeader",
      "watermark_col_name": "int_col",
      "watermark_col_type": "int",
      "watermark_col_start_value": 0
    },
    "task_enabled": 0
  },
  {
    "job_name": "lakefed_ingest",
    "source": {
      "catalog": "lakefed_azuresql",
      "schema": "SalesLT",
      "table": "SalesOrderHeader"
    },
    "sink": {
      "catalog": "lakefed_sink",
      "schema": "SalesLT",
      "table": "SalesOrderHeader"
    },
    "load_settings": {
      "type": "incremental",
      "query": "select * from lakefed_azuresql.SalesLT.SalesOrderHeader",
      "watermark_col_name": "timestamp_col",
      "watermark_col_type": "timestamp",
      "watermark_col_start_value": "1900-01-01"
    },
    "task_enabled": 0
  }
]'; 

insert into lakefed_bulk_ingest.default.control(
  job_name,
  task_collection,
  src_catalog,
  src_schema,
  src_table,
  sink_catalog,
  sink_schema,
  sink_table,
  load_type,
  select_list,
  watermark_col_name,
  watermark_col_type,
  watermark_col_start_value,
  task_enabled
)
select
value:job_name::string,
'adventureworks' as task_collection,
value:source.catalog::string as src_catalog,
value:source.schema::string as src_schema,
value:source.table::string as src_table,
value:sink.catalog::string as sink_catalog,
value:sink.schema::string as sink_schema,
value:sink.table::string as sink_table,
value:load_settings.type::string as load_type,
'*' as select_list,
value:load_settings.watermark_col_name::string as watermark_col_name,
value:load_settings.watermark_col_type::string as watermark_col_type,
value:load_settings.watermark_col_start_value::string as watermark_col_start_value,
value:task_enabled::boolean as task_enabled
from variant_explode(parse_json(metadata_json));
